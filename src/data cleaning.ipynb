# %%
import pandas as pd 
import numpy as np 
import re

# %%
finance=pd.read_csv(r'E:\.A Data Analyst\Excel\Project 4 raw Data.csv')

# %%
finance.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transaction_id      5000 non-null   int64
#  1   transaction_date    5000 non-null   object
#  2   posting_date        4681 non-null   object
#  3   currency            5000 non-null   object
#  4   amount              5000 non-null   object
#  5   transaction_type    5000 non-null   object
#  6   category            5000 non-null   object
#  7   sub_category        5000 non-null   object
#  8   counterparty        5000 non-null   object
#  9   payment_method      5000 non-null   object
#  10  department          5000 non-null   object
#  11  cost_center         5000 non-null   object
#  12  transaction_status  5000 non-null   object
#  13   invoice_id         5000 non-null   object
#  14  due_date            5000 non-null   object
# ...

# %%
finance['transaction_date']=pd.to_datetime(finance['transaction_date'],format='%d-%m-%Y')
finance['transaction_date'].head()
# Out:
# 0   2023-09-20
# 1   2023-10-21
# 2   2024-08-18
# 3   2024-03-19
# 4   2024-09-27
# Name: transaction_date, dtype: datetime64[ns]

# %%
finance['posting_date']=pd.to_datetime(finance['posting_date'],format='%d-%m-%Y')
finance['posting_date'].head()
# Out:
# 0   2023-04-11
# 1   2024-06-09
# 2   2024-04-14
# 3   2024-03-30
# 4   2024-02-23
# Name: posting_date, dtype: datetime64[ns]

# %%
finance['due_date']=pd.to_datetime(finance['due_date'],dayfirst=True,format='mixed')
finance['due_date'].head()
# Out:
# 0   2023-07-24
# 1   2023-04-28
# 2   2024-05-25
# 3   2024-02-20
# 4   2024-11-02
# Name: due_date, dtype: datetime64[ns]

# %%
finance['settlement_date']=pd.to_datetime(finance['settlement_date'],format='mixed')
finance['settlement_date'].head()
# Out:
# 0   2025-01-21
# 1   2023-01-23
# 2   2023-08-12
# 3   2025-02-21
# 4   2024-10-08
# Name: settlement_date, dtype: datetime64[ns]

# %%
finance['amount']=pd.to_numeric(finance['amount'].astype(str).str.replace('$',''))

# %%
finance['amount']=pd.to_numeric(finance['amount'].astype(float))

# %%
finance['amount'].isna().sum()
# Out:
# 0

# %%
finance['expense']=finance['amount'].where(finance['amount']<0,0)

# %%
finance['expense'].isna().sum()
# Out:
# 0

# %%
finance['expense']=pd.to_numeric(finance['expense'].astype(str).str.replace('-',''))

# %%
finance['expense']
# Out:
# 0           0.00
# 1           0.00
# 2           0.00
# 3       14065.47
# 4           0.00
#           ...
# 4995        0.00
# 4996        0.00
# 4997        0.00
# 4998        0.00
# 4999        0.00
# Name: expense, Length: 5000, dtype: float64

# %%
finance['amount']=finance['amount'].where(finance['amount']>=0,0)

# %%
finance['amount']
# Out:
# 0       103153.24
# 1        18098.84
# 2       182595.71
# 3            0.00
# 4        88570.59
#           ...
# 4995    183420.03
# 4996    165232.96
# 4997    156621.85
# 4998    137931.72
# 4999    188121.03
# Name: amount, Length: 5000, dtype: float64

# %%
finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transaction_id      5000 non-null   int64
#  1   transaction_date    5000 non-null   datetime64[ns]
#  2   posting_date        4681 non-null   datetime64[ns]
#  3   currency            5000 non-null   object
#  4   amount              5000 non-null   float64
#  5   transaction_type    5000 non-null   object
#  6   category            5000 non-null   object
#  7   sub_category        5000 non-null   object
#  8   counterparty        5000 non-null   object
#  9   payment_method      5000 non-null   object
#  10  department          5000 non-null   object
#  11  cost_center         5000 non-null   object
#  12  transaction_status  5000 non-null   object
#  13   invoice_id         5000 non-null   object
#  14  due_date            5000 non-null   datetime64[ns]
# ...

# %%
finance.isna().sum()
# Out:
# transaction_id          0
# transaction_date        0
# posting_date          319
# currency                0
# amount                  0
# transaction_type        0
# category                0
# sub_category            0
# counterparty            0
# payment_method          0
# department              0
# cost_center             0
# transaction_status      0
#  invoice_id             0
# due_date                0
# settlement_date         0
# expense                 0
# dtype: int64

# %%
path=r'E:\.A Data Analyst\Projects\Finance_Advanced\finance_cleaned.csv'
finance.to_csv(path,index=False)
